# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col=0).squeeze()
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test  = pd.read_csv('loan_data_targets_test.csv', index_col=0).squeeze()

# %% [markdown]
# ### Explore Data

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86
# 427211                            0                           0
# 206088                            0                           0
# 136020                            0                           0
# 412305                            0                           0
# 36159                             0                           0
#
# [5 rows x 324 columns]

# %%
loan_data_targets_train.head()
# Out:
# 427211    1
# 206088    1
# 136020    1
# 412305    0
# 36159     0
# Name: good_bad, dtype: int64

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 324)

# %%
loan_data_targets_train.shape
# Out:
# (373028,)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 324)

# %%
loan_data_targets_test.shape
# Out:
# (93257,)

# %% [markdown]
# ### Selecting the Features

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211     True    False    False    False    False    False
# 206088    False    False     True    False    False    False
# 136020     True    False    False    False    False    False
# 412305    False    False    False     True    False    False
# 36159     False    False     True    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211               False                     True                 0
# 206088               False                     True                 0
# 136020               False                     True                 0
# 412305               False                    False                 0
# 36159                False                     True                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211          False  ...                               1
# 206088          False  ...                               0
# 136020          False  ...                               0
# 412305          False  ...                               0
# 36159           False  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 104 columns]

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-0.43971587])

# %%
reg.coef_
# Out:
# array([[ 0.96196135,  0.75620154,  0.57318469,  0.39424493,  0.24446379,
#          0.07257649,  0.090125  ,  0.10651929,  0.0444755 ,  0.07042988,
#          0.06873953,  0.07264459,  0.08858091,  0.14755557,  0.11571508,
#          0.19791378,  0.24641881,  0.23559442,  0.27551432,  0.33704383,
#          0.4995498 ,  0.08208947, -0.01507377,  0.2751258 ,  0.17032881,
#          0.17946097,  0.23172234,  0.05184719,  0.07697977,  0.1098932 ,
#          0.13363751,  0.10027556,  0.0680862 ,  0.13035687,  1.12999152,
#          0.94066969,  0.84172437,  0.64624131,  0.48722962,  0.24237926,
#         -0.00806157,  0.97767401,  0.62847791,  0.36324554,  0.1497359 ,
#          0.08350252,  0.06078775,  0.08796385,  0.14203302,  0.14586471,
#         -0.04061186, -0.06709315,  0.28849972,  0.14459279, -0.06570191,
#          0.07260405, -0.0414536 , -0.06783526, -0.09237475, -0.07533364,
#         -0.0516863 , -0.108156  ,  0.13284916,  0.0910544 , -0.01930056,
#          0.03060386,  0.16442319,  0.04318141,  0.0087281 ,  0.00348577,
#          0.01900504,  0.03489218,  0.06102815,  0.20465093, -0.18097848,
#         -0.10954368, -0.01129966,  0.05740958,  0.13489227,  0.20665309,
#          0.27964664,  0.29475605,  0.37448554,  0.49717429,  0.40190641,
#          0.05289476,  0.17468209,  0.19744689,  0.13812899,  0.06307658,
#         -0.0349585 , -0.04952897, -0.08320383, -0.11974226,  0.07750114,
#          0.12422369,  0.15242796,  0.10453007,  0.11891414,  0.20646415,
#          0.12910125,  0.29530528, -0.06203283,  0.02276902]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -0.439716
# 1                                grade:A      0.961961
# 2                                grade:B      0.756202
# 3                                grade:C      0.573185
# 4                                grade:D      0.394245
# 5                                grade:E      0.244464
# 6                                grade:F      0.072576
# 7                     home_ownership:OWN      0.090125
# 8                home_ownership:MORTGAGE      0.106519
# 9                       addr_state:NM_VA      0.044476
# 10                         addr_state:NY      0.070430
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.068740
# 12                         addr_state:CA      0.072645
# 13                addr_state:UT_KY_AZ_NJ      0.088581
# 14             addr_state:AR_MI_PA_OH_MN      0.147556
# 15             addr_state:RI_MA_DE_SD_IN      0.115715
# 16                   addr_state:GA_WA_OR      0.197914
# 17                      addr_state:WI_MT      0.246419
# 18                         addr_state:TX      0.235594
# 19                      addr_state:IL_CT      0.275514
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.337044
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.499550
# 22      verification_status:Not Verified      0.082089
# 23   verification_status:Source Verified     -0.015074
# 24                   purpose:credit_card      0.275126
# 25            purpose:debt_consolidation      0.170329
# 26            purpose:oth__med__vacation      0.179461
# 27   purpose:major_purch__car__home_impr      0.231722
# 28                 initial_list_status:w      0.051847
# 29                               term:36      0.076980
# 30                          emp_length:1      0.109893
# 31                        emp_length:2-4      0.133638
# 32                        emp_length:5-6      0.100276
# 33                        emp_length:7-9      0.068086
# 34                         emp_length:10      0.130357
# 35                mths_since_issue_d:<38      1.129992
# 36              mths_since_issue_d:38-39      0.940670
# 37              mths_since_issue_d:40-41      0.841724
# 38              mths_since_issue_d:42-48      0.646241
# 39              mths_since_issue_d:49-52      0.487230
# 40              mths_since_issue_d:53-64      0.242379
# 41              mths_since_issue_d:65-84     -0.008062
# 42                       int_rate:<9.548      0.977674
# 43                 int_rate:9.548-12.025      0.628478
# 44                 int_rate:12.025-15.74      0.363246
# 45                 int_rate:15.74-20.281      0.149736
# 46   mths_since_earliest_cr_line:141-164      0.083503
# 47   mths_since_earliest_cr_line:165-247      0.060788
# 48   mths_since_earliest_cr_line:248-270      0.087964
# 49   mths_since_earliest_cr_line:271-352      0.142033
# 50      mths_since_earliest_cr_line:>352      0.145865
# 51                         delinq_2yrs:0     -0.040612
# 52                       delinq_2yrs:1-3     -0.067093
# 53                      inq_last_6mths:0      0.288500
# 54                    inq_last_6mths:1-2      0.144593
# 55                    inq_last_6mths:3-6     -0.065702
# 56                          open_acc:1-3      0.072604
# 57                         open_acc:4-12     -0.041454
# 58                        open_acc:13-17     -0.067835
# 59                        open_acc:18-22     -0.092375
# 60                        open_acc:23-25     -0.075334
# 61                        open_acc:26-30     -0.051686
# 62                         open_acc:>=31     -0.108156
# 63                           pub_rec:3-4      0.132849
# 64                           pub_rec:>=5      0.091054
# 65                       total_acc:28-51     -0.019301
# 66                        total_acc:>=52      0.030604
# 67                    acc_now_delinq:>=1      0.164423
# 68               total_rev_hi_lim:5K-10K      0.043181
# 69              total_rev_hi_lim:10K-20K      0.008728
# 70              total_rev_hi_lim:20K-30K      0.003486
# 71              total_rev_hi_lim:30K-40K      0.019005
# 72              total_rev_hi_lim:40K-55K      0.034892
# 73              total_rev_hi_lim:55K-95K      0.061028
# 74                 total_rev_hi_lim:>95K      0.204651
# 75                    annual_inc:20K-30K     -0.180978
# 76                    annual_inc:30K-40K     -0.109544
# 77                    annual_inc:40K-50K     -0.011300
# 78                    annual_inc:50K-60K      0.057410
# 79                    annual_inc:60K-70K      0.134892
# 80                    annual_inc:70K-80K      0.206653
# 81                    annual_inc:80K-90K      0.279647
# 82                   annual_inc:90K-100K      0.294756
# 83                  annual_inc:100K-120K      0.374486
# 84                  annual_inc:120K-140K      0.497174
# 85                      annual_inc:>140K      0.401906
# 86                             dti:<=1.4      0.052895
# 87                           dti:1.4-3.5      0.174682
# 88                           dti:3.5-7.7      0.197447
# 89                          dti:7.7-10.5      0.138129
# 90                         dti:10.5-16.1      0.063077
# 91                         dti:16.1-20.3     -0.034958
# 92                         dti:20.3-21.7     -0.049529
# 93                         dti:21.7-22.4     -0.083204
# 94                           dti:22.4-35     -0.119742
# 95        mths_since_last_delinq:Missing      0.077501
# 96           mths_since_last_delinq:4-30      0.124224
# 97          mths_since_last_delinq:31-56      0.152428
# 98           mths_since_last_delinq:>=57      0.104530
# 99        mths_since_last_record:Missing      0.118914
# 100          mths_since_last_record:3-20      0.206464
# 101         mths_since_last_record:21-31      0.129101
# 102         mths_since_last_record:32-80      0.295305
# 103         mths_since_last_record:81-86     -0.062033
# 104          mths_since_last_record:>=86      0.022769

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
X = inputs_train.copy()

# 1) 强制把所有列转成数值（转不了的变 NaN）
X = X.apply(pd.to_numeric, errors='coerce')

# 2) 处理 inf / NaN
X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0)

# 3) 确保是 float
X = X.astype('float64')

# y 也整理成一维数值
y = loan_data_targets_train.squeeze()
y = pd.to_numeric(y, errors='coerce')

reg.fit(X, y)

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -0.439716
# 1                                grade:A      0.961961
# 2                                grade:B      0.756202
# 3                                grade:C      0.573185
# 4                                grade:D      0.394245
# 5                                grade:E      0.244464
# 6                                grade:F      0.072576
# 7                     home_ownership:OWN      0.090125
# 8                home_ownership:MORTGAGE      0.106519
# 9                       addr_state:NM_VA      0.044476
# 10                         addr_state:NY      0.070430
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.068740
# 12                         addr_state:CA      0.072645
# 13                addr_state:UT_KY_AZ_NJ      0.088581
# 14             addr_state:AR_MI_PA_OH_MN      0.147556
# 15             addr_state:RI_MA_DE_SD_IN      0.115715
# 16                   addr_state:GA_WA_OR      0.197914
# 17                      addr_state:WI_MT      0.246419
# 18                         addr_state:TX      0.235594
# 19                      addr_state:IL_CT      0.275514
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.337044
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.499550
# 22      verification_status:Not Verified      0.082089
# 23   verification_status:Source Verified     -0.015074
# 24                   purpose:credit_card      0.275126
# 25            purpose:debt_consolidation      0.170329
# 26            purpose:oth__med__vacation      0.179461
# 27   purpose:major_purch__car__home_impr      0.231722
# 28                 initial_list_status:w      0.051847
# 29                               term:36      0.076980
# 30                          emp_length:1      0.109893
# 31                        emp_length:2-4      0.133638
# 32                        emp_length:5-6      0.100276
# 33                        emp_length:7-9      0.068086
# 34                         emp_length:10      0.130357
# 35                mths_since_issue_d:<38      1.129992
# 36              mths_since_issue_d:38-39      0.940670
# 37              mths_since_issue_d:40-41      0.841724
# 38              mths_since_issue_d:42-48      0.646241
# 39              mths_since_issue_d:49-52      0.487230
# 40              mths_since_issue_d:53-64      0.242379
# 41              mths_since_issue_d:65-84     -0.008062
# 42                       int_rate:<9.548      0.977674
# 43                 int_rate:9.548-12.025      0.628478
# 44                 int_rate:12.025-15.74      0.363246
# 45                 int_rate:15.74-20.281      0.149736
# 46   mths_since_earliest_cr_line:141-164      0.083503
# 47   mths_since_earliest_cr_line:165-247      0.060788
# 48   mths_since_earliest_cr_line:248-270      0.087964
# 49   mths_since_earliest_cr_line:271-352      0.142033
# 50      mths_since_earliest_cr_line:>352      0.145865
# 51                         delinq_2yrs:0     -0.040612
# 52                       delinq_2yrs:1-3     -0.067093
# 53                      inq_last_6mths:0      0.288500
# 54                    inq_last_6mths:1-2      0.144593
# 55                    inq_last_6mths:3-6     -0.065702
# 56                          open_acc:1-3      0.072604
# 57                         open_acc:4-12     -0.041454
# 58                        open_acc:13-17     -0.067835
# 59                        open_acc:18-22     -0.092375
# 60                        open_acc:23-25     -0.075334
# 61                        open_acc:26-30     -0.051686
# 62                         open_acc:>=31     -0.108156
# 63                           pub_rec:3-4      0.132849
# 64                           pub_rec:>=5      0.091054
# 65                       total_acc:28-51     -0.019301
# 66                        total_acc:>=52      0.030604
# 67                    acc_now_delinq:>=1      0.164423
# 68               total_rev_hi_lim:5K-10K      0.043181
# 69              total_rev_hi_lim:10K-20K      0.008728
# 70              total_rev_hi_lim:20K-30K      0.003486
# 71              total_rev_hi_lim:30K-40K      0.019005
# 72              total_rev_hi_lim:40K-55K      0.034892
# 73              total_rev_hi_lim:55K-95K      0.061028
# 74                 total_rev_hi_lim:>95K      0.204651
# 75                    annual_inc:20K-30K     -0.180978
# 76                    annual_inc:30K-40K     -0.109544
# 77                    annual_inc:40K-50K     -0.011300
# 78                    annual_inc:50K-60K      0.057410
# 79                    annual_inc:60K-70K      0.134892
# 80                    annual_inc:70K-80K      0.206653
# 81                    annual_inc:80K-90K      0.279647
# 82                   annual_inc:90K-100K      0.294756
# 83                  annual_inc:100K-120K      0.374486
# 84                  annual_inc:120K-140K      0.497174
# 85                      annual_inc:>140K      0.401906
# 86                             dti:<=1.4      0.052895
# 87                           dti:1.4-3.5      0.174682
# 88                           dti:3.5-7.7      0.197447
# 89                          dti:7.7-10.5      0.138129
# 90                         dti:10.5-16.1      0.063077
# 91                         dti:16.1-20.3     -0.034958
# 92                         dti:20.3-21.7     -0.049529
# 93                         dti:21.7-22.4     -0.083204
# 94                           dti:22.4-35     -0.119742
# 95        mths_since_last_delinq:Missing      0.077501
# 96           mths_since_last_delinq:4-30      0.124224
# 97          mths_since_last_delinq:31-56      0.152428
# 98           mths_since_last_delinq:>=57      0.104530
# 99        mths_since_last_record:Missing      0.118914
# 100          mths_since_last_record:3-20      0.206464
# 101         mths_since_last_record:21-31      0.129101
# 102         mths_since_last_record:32-80      0.295305
# 103         mths_since_last_record:81-86     -0.062033
# 104          mths_since_last_record:>=86      0.022769

# %%
p_values = reg.p_values

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept     -0.439716            NaN
# 1                                grade:A      0.961961   7.899640e-26
# 2                                grade:B      0.756202   1.397796e-34
# 3                                grade:C      0.573185   1.390495e-23
# 4                                grade:D      0.394245   4.493207e-13
# 5                                grade:E      0.244464   5.421829e-07
# 6                                grade:F      0.072576   1.533975e-01
# 7                     home_ownership:OWN      0.090125   7.997812e-06
# 8                home_ownership:MORTGAGE      0.106519   4.911302e-17
# 9                       addr_state:NM_VA      0.044476   1.648550e-01
# 10                         addr_state:NY      0.070430   3.699568e-03
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.068740   3.017306e-03
# 12                         addr_state:CA      0.072645   6.130574e-04
# 13                addr_state:UT_KY_AZ_NJ      0.088581   3.793785e-04
# 14             addr_state:AR_MI_PA_OH_MN      0.147556   6.044156e-11
# 15             addr_state:RI_MA_DE_SD_IN      0.115715   1.081253e-04
# 16                   addr_state:GA_WA_OR      0.197914   1.252896e-13
# 17                      addr_state:WI_MT      0.246419   2.178369e-07
# 18                         addr_state:TX      0.235594   1.290031e-19
# 19                      addr_state:IL_CT      0.275514   4.552450e-21
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.337044   1.083967e-27
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.499550   2.203384e-21
# 22      verification_status:Not Verified      0.082089   2.318087e-08
# 23   verification_status:Source Verified     -0.015074   2.632991e-01
# 24                   purpose:credit_card      0.275126   7.237789e-22
# 25            purpose:debt_consolidation      0.170329   1.039435e-10
# 26            purpose:oth__med__vacation      0.179461   1.072926e-08
# 27   purpose:major_purch__car__home_impr      0.231722   1.927546e-13
# 28                 initial_list_status:w      0.051847   7.192005e-05
# 29                               term:36      0.076980   5.640176e-08
# 30                          emp_length:1      0.109893   2.328179e-05
# 31                        emp_length:2-4      0.133638   1.449293e-12
# 32                        emp_length:5-6      0.100276   2.802443e-06
# 33                        emp_length:7-9      0.068086   1.057451e-03
# 34                         emp_length:10      0.130357   1.504050e-12
# 35                mths_since_issue_d:<38      1.129992  1.159094e-192
# 36              mths_since_issue_d:38-39      0.940670  2.275815e-166
# 37              mths_since_issue_d:40-41      0.841724  2.980074e-140
# 38              mths_since_issue_d:42-48      0.646241  1.055581e-105
# 39              mths_since_issue_d:49-52      0.487230   1.206994e-53
# 40              mths_since_issue_d:53-64      0.242379   3.490018e-16
# 41              mths_since_issue_d:65-84     -0.008062   7.803812e-01
# 42                       int_rate:<9.548      0.977674   3.571331e-37
# 43                 int_rate:9.548-12.025      0.628478   1.856125e-44
# 44                 int_rate:12.025-15.74      0.363246   8.929199e-23
# 45                 int_rate:15.74-20.281      0.149736   2.895368e-07
# 46   mths_since_earliest_cr_line:141-164      0.083503   1.046445e-03
# 47   mths_since_earliest_cr_line:165-247      0.060788   3.530145e-03
# 48   mths_since_earliest_cr_line:248-270      0.087964   1.077982e-03
# 49   mths_since_earliest_cr_line:271-352      0.142033   4.760231e-09
# 50      mths_since_earliest_cr_line:>352      0.145865   6.656094e-08
# 51                         delinq_2yrs:0     -0.040612   4.895004e-01
# 52                       delinq_2yrs:1-3     -0.067093   2.270267e-01
# 53                      inq_last_6mths:0      0.288500   1.853984e-02
# 54                    inq_last_6mths:1-2      0.144593   2.373801e-01
# 55                    inq_last_6mths:3-6     -0.065702   5.927352e-01
# 56                          open_acc:1-3      0.072604   6.733197e-01
# 57                         open_acc:4-12     -0.041454   8.055933e-01
# 58                        open_acc:13-17     -0.067835   6.876797e-01
# 59                        open_acc:18-22     -0.092375   5.861623e-01
# 60                        open_acc:23-25     -0.075334   6.653894e-01
# 61                        open_acc:26-30     -0.051686   7.731006e-01
# 62                         open_acc:>=31     -0.108156   5.759665e-01
# 63                           pub_rec:3-4      0.132849   1.621753e-01
# 64                           pub_rec:>=5      0.091054   6.246564e-01
# 65                       total_acc:28-51     -0.019301   1.740412e-01
# 66                        total_acc:>=52      0.030604   4.420284e-01
# 67                    acc_now_delinq:>=1      0.164423   1.210966e-01
# 68               total_rev_hi_lim:5K-10K      0.043181   7.962187e-02
# 69              total_rev_hi_lim:10K-20K      0.008728   7.147004e-01
# 70              total_rev_hi_lim:20K-30K      0.003486   8.943182e-01
# 71              total_rev_hi_lim:30K-40K      0.019005   5.188887e-01
# 72              total_rev_hi_lim:40K-55K      0.034892   2.778558e-01
# 73              total_rev_hi_lim:55K-95K      0.061028   9.040442e-02
# 74                 total_rev_hi_lim:>95K      0.204651   2.988581e-04
# 75                    annual_inc:20K-30K     -0.180978   4.099521e-05
# 76                    annual_inc:30K-40K     -0.109544   1.027373e-02
# 77                    annual_inc:40K-50K     -0.011300   7.914195e-01
# 78                    annual_inc:50K-60K      0.057410   1.848430e-01
# 79                    annual_inc:60K-70K      0.134892   2.317109e-03
# 80                    annual_inc:70K-80K      0.206653   4.748435e-06
# 81                    annual_inc:80K-90K      0.279647   2.529387e-09
# 82                   annual_inc:90K-100K      0.294756   1.195218e-09
# 83                  annual_inc:100K-120K      0.374486   7.935190e-15
# 84                  annual_inc:120K-140K      0.497174   8.033850e-20
# 85                      annual_inc:>140K      0.401906   2.066799e-15
# 86                             dti:<=1.4      0.052895   5.615531e-01
# 87                           dti:1.4-3.5      0.174682   2.479398e-02
# 88                           dti:3.5-7.7      0.197447   4.009441e-03
# 89                          dti:7.7-10.5      0.138129   4.243348e-02
# 90                         dti:10.5-16.1      0.063077   3.406066e-01
# 91                         dti:16.1-20.3     -0.034958   5.972112e-01
# 92                         dti:20.3-21.7     -0.049529   4.694839e-01
# 93                         dti:21.7-22.4     -0.083204   2.484633e-01
# 94                           dti:22.4-35     -0.119742   6.730718e-02
# 95        mths_since_last_delinq:Missing      0.077501   1.752110e-01
# 96           mths_since_last_delinq:4-30      0.124224   1.923575e-02
# 97          mths_since_last_delinq:31-56      0.152428   8.954750e-03
# 98           mths_since_last_delinq:>=57      0.104530   7.875517e-02
# 99        mths_since_last_record:Missing      0.118914   1.264528e-01
# 100          mths_since_last_record:3-20      0.206464   8.899403e-02
# 101         mths_since_last_record:21-31      0.129101   2.422441e-01
# 102         mths_since_last_record:32-80      0.295305   3.213121e-04
# 103         mths_since_last_record:81-86     -0.062033   4.811252e-01
# 104          mths_since_last_record:>=86      0.022769   7.736471e-01

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211     True    False    False    False    False    False
# 206088    False    False     True    False    False    False
# 136020     True    False    False    False    False    False
# 412305    False    False    False     True    False    False
# 36159     False    False     True    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211               False                     True                 0
# 206088               False                     True                 0
# 136020               False                     True                 0
# 412305               False                    False                 0
# 36159                False                     True                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211          False  ...                               1
# 206088          False  ...                               0
# 136020          False  ...                               0
# 412305          False  ...                               0
# 36159           False  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 84 columns]

# %%
X = inputs_train.copy()
X = X.apply(pd.to_numeric, errors='coerce')
X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0).astype('float64')

y = loan_data_targets_train.squeeze()
y = pd.to_numeric(y, errors='coerce')
reg2 = LogisticRegression_with_p_values()
reg2.fit(X, y)

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -0.422337
# 1                               grade:A      0.938487
# 2                               grade:B      0.723337
# 3                               grade:C      0.539683
# 4                               grade:D      0.363004
# 5                               grade:E      0.207573
# 6                               grade:F      0.038482
# 7                    home_ownership:OWN      0.095920
# 8               home_ownership:MORTGAGE      0.105635
# 9                      addr_state:NM_VA      0.044536
# 10                        addr_state:NY      0.070186
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.067430
# 12                        addr_state:CA      0.074802
# 13               addr_state:UT_KY_AZ_NJ      0.089461
# 14            addr_state:AR_MI_PA_OH_MN      0.145470
# 15            addr_state:RI_MA_DE_SD_IN      0.113015
# 16                  addr_state:GA_WA_OR      0.197015
# 17                     addr_state:WI_MT      0.241572
# 18                        addr_state:TX      0.234072
# 19                     addr_state:IL_CT      0.272644
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.338343
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500987
# 22     verification_status:Not Verified      0.080313
# 23  verification_status:Source Verified     -0.013690
# 24                  purpose:credit_card      0.282217
# 25           purpose:debt_consolidation      0.176831
# 26           purpose:oth__med__vacation      0.186707
# 27  purpose:major_purch__car__home_impr      0.242267
# 28                initial_list_status:w      0.049335
# 29                              term:36      0.080517
# 30                         emp_length:1      0.107552
# 31                       emp_length:2-4      0.133254
# 32                       emp_length:5-6      0.099304
# 33                       emp_length:7-9      0.067018
# 34                        emp_length:10      0.129969
# 35               mths_since_issue_d:<38      1.134130
# 36             mths_since_issue_d:38-39      0.941203
# 37             mths_since_issue_d:40-41      0.841799
# 38             mths_since_issue_d:42-48      0.650616
# 39             mths_since_issue_d:49-52      0.485555
# 40             mths_since_issue_d:53-64      0.240577
# 41             mths_since_issue_d:65-84     -0.010876
# 42                      int_rate:<9.548      0.962494
# 43                int_rate:9.548-12.025      0.624652
# 44                int_rate:12.025-15.74      0.360737
# 45                int_rate:15.74-20.281      0.149148
# 46  mths_since_earliest_cr_line:141-164      0.082451
# 47  mths_since_earliest_cr_line:165-247      0.060096
# 48  mths_since_earliest_cr_line:248-270      0.089109
# 49  mths_since_earliest_cr_line:271-352      0.145738
# 50     mths_since_earliest_cr_line:>352      0.153185
# 51                     inq_last_6mths:0      0.271013
# 52                   inq_last_6mths:1-2      0.127457
# 53                   inq_last_6mths:3-6     -0.084082
# 54                   acc_now_delinq:>=1      0.147346
# 55                   annual_inc:20K-30K     -0.182116
# 56                   annual_inc:30K-40K     -0.119744
# 57                   annual_inc:40K-50K     -0.024551
# 58                   annual_inc:50K-60K      0.040613
# 59                   annual_inc:60K-70K      0.118618
# 60                   annual_inc:70K-80K      0.189210
# 61                   annual_inc:80K-90K      0.264746
# 62                  annual_inc:90K-100K      0.277489
# 63                 annual_inc:100K-120K      0.357331
# 64                 annual_inc:120K-140K      0.471519
# 65                     annual_inc:>140K      0.387981
# 66                            dti:<=1.4      0.056863
# 67                          dti:1.4-3.5      0.162534
# 68                          dti:3.5-7.7      0.200501
# 69                         dti:7.7-10.5      0.134487
# 70                        dti:10.5-16.1      0.055614
# 71                        dti:16.1-20.3     -0.046302
# 72                        dti:20.3-21.7     -0.063478
# 73                        dti:21.7-22.4     -0.093507
# 74                          dti:22.4-35     -0.137984
# 75       mths_since_last_delinq:Missing      0.078757
# 76          mths_since_last_delinq:4-30      0.102983
# 77         mths_since_last_delinq:31-56      0.146209
# 78          mths_since_last_delinq:>=57      0.097781
# 79       mths_since_last_record:Missing      0.098030
# 80          mths_since_last_record:3-20      0.207409
# 81         mths_since_last_record:21-31      0.122619
# 82         mths_since_last_record:32-80      0.272275
# 83         mths_since_last_record:81-86     -0.091413
# 84          mths_since_last_record:>=86     -0.007091

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -0.422337            NaN
# 1                               grade:A      0.938487   8.628895e-25
# 2                               grade:B      0.723337   9.350272e-32
# 3                               grade:C      0.539683   4.047793e-21
# 4                               grade:D      0.363004   2.279373e-11
# 5                               grade:E      0.207573   1.686471e-05
# 6                               grade:F      0.038482   4.423036e-01
# 7                    home_ownership:OWN      0.095920   1.988507e-06
# 8               home_ownership:MORTGAGE      0.105635   6.495912e-17
# 9                      addr_state:NM_VA      0.044536   1.637228e-01
# 10                        addr_state:NY      0.070186   3.734219e-03
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.067430   3.533622e-03
# 12                        addr_state:CA      0.074802   4.081311e-04
# 13               addr_state:UT_KY_AZ_NJ      0.089461   3.243376e-04
# 14            addr_state:AR_MI_PA_OH_MN      0.145470   9.956686e-11
# 15            addr_state:RI_MA_DE_SD_IN      0.113015   1.512984e-04
# 16                  addr_state:GA_WA_OR      0.197015   1.438942e-13
# 17                     addr_state:WI_MT      0.241572   3.541934e-07
# 18                        addr_state:TX      0.234072   1.951314e-19
# 19                     addr_state:IL_CT      0.272644   9.572646e-21
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.338343   6.271619e-28
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.500987   1.665499e-21
# 22     verification_status:Not Verified      0.080313   3.701709e-08
# 23  verification_status:Source Verified     -0.013690   3.080972e-01
# 24                  purpose:credit_card      0.282217   2.798126e-23
# 25           purpose:debt_consolidation      0.176831   1.307049e-11
# 26           purpose:oth__med__vacation      0.186707   2.131028e-09
# 27  purpose:major_purch__car__home_impr      0.242267   9.966835e-15
# 28                initial_list_status:w      0.049335   1.578363e-04
# 29                              term:36      0.080517   8.423244e-09
# 30                         emp_length:1      0.107552   3.389306e-05
# 31                       emp_length:2-4      0.133254   1.610511e-12
# 32                       emp_length:5-6      0.099304   3.448010e-06
# 33                       emp_length:7-9      0.067018   1.261339e-03
# 34                        emp_length:10      0.129969   1.704308e-12
# 35               mths_since_issue_d:<38      1.134130  1.656006e-202
# 36             mths_since_issue_d:38-39      0.941203  1.697586e-175
# 37             mths_since_issue_d:40-41      0.841799  2.287649e-148
# 38             mths_since_issue_d:42-48      0.650616  2.489846e-114
# 39             mths_since_issue_d:49-52      0.485555   1.710851e-56
# 40             mths_since_issue_d:53-64      0.240577   6.271426e-17
# 41             mths_since_issue_d:65-84     -0.010876   7.057533e-01
# 42                      int_rate:<9.548      0.962494   1.601199e-36
# 43                int_rate:9.548-12.025      0.624652   1.827099e-44
# 44                int_rate:12.025-15.74      0.360737   9.131108e-23
# 45                int_rate:15.74-20.281      0.149148   2.741209e-07
# 46  mths_since_earliest_cr_line:141-164      0.082451   1.149131e-03
# 47  mths_since_earliest_cr_line:165-247      0.060096   3.434572e-03
# 48  mths_since_earliest_cr_line:248-270      0.089109   7.817254e-04
# 49  mths_since_earliest_cr_line:271-352      0.145738   8.681115e-10
# 50     mths_since_earliest_cr_line:>352      0.153185   7.212413e-09
# 51                     inq_last_6mths:0      0.271013   2.982340e-03
# 52                   inq_last_6mths:1-2      0.127457   1.621253e-01
# 53                   inq_last_6mths:3-6     -0.084082   3.592526e-01
# 54                   acc_now_delinq:>=1      0.147346   1.649123e-01
# 55                   annual_inc:20K-30K     -0.182116   2.444058e-05
# 56                   annual_inc:30K-40K     -0.119744   3.962551e-03
# 57                   annual_inc:40K-50K     -0.024551   5.542120e-01
# 58                   annual_inc:50K-60K      0.040613   3.337015e-01
# 59                   annual_inc:60K-70K      0.118618   5.720689e-03
# 60                   annual_inc:70K-80K      0.189210   1.517388e-05
# 61                   annual_inc:80K-90K      0.264746   5.766220e-09
# 62                  annual_inc:90K-100K      0.277489   3.474371e-09
# 63                 annual_inc:100K-120K      0.357331   1.746542e-14
# 64                 annual_inc:120K-140K      0.471519   5.064018e-19
# 65                     annual_inc:>140K      0.387981   1.250091e-15
# 66                            dti:<=1.4      0.056863   5.071929e-01
# 67                          dti:1.4-3.5      0.162534   2.555118e-02
# 68                          dti:3.5-7.7      0.200501   1.654615e-03
# 69                         dti:7.7-10.5      0.134487   3.382894e-02
# 70                        dti:10.5-16.1      0.055614   3.656689e-01
# 71                        dti:16.1-20.3     -0.046302   4.519732e-01
# 72                        dti:20.3-21.7     -0.063478   3.220510e-01
# 73                        dti:21.7-22.4     -0.093507   1.689765e-01
# 74                          dti:22.4-35     -0.137984   2.353550e-02
# 75       mths_since_last_delinq:Missing      0.078757   1.306895e-01
# 76          mths_since_last_delinq:4-30      0.102983   5.079108e-02
# 77         mths_since_last_delinq:31-56      0.146209   6.164925e-03
# 78          mths_since_last_delinq:>=57      0.097781   7.356157e-02
# 79       mths_since_last_record:Missing      0.098030   1.875488e-01
# 80          mths_since_last_record:3-20      0.207409   7.913877e-02
# 81         mths_since_last_record:21-31      0.122619   2.540697e-01
# 82         mths_since_last_record:32-80      0.272275   5.369434e-04
# 83         mths_since_last_record:81-86     -0.091413   2.864814e-01
# 84          mths_since_last_record:>=86     -0.007091   9.256037e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))

# %% [markdown]
# # PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation (test)

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514    False    False     True    False    False    False
# 288564    False    False    False    False     True    False
# 213591    False    False     True    False    False    False
# 263083    False    False     True    False    False    False
# 165001     True    False    False    False    False    False
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514               False                     True                 0
# 288564               False                     True                 0
# 213591               False                     True                 0
# 263083               False                     True                 0
# 165001               False                     True                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 362514          False  ...                               1
# 288564          False  ...                               0
# 213591          False  ...                               0
# 263083          False  ...                               1
# 165001          False  ...                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>=86
# 362514                            0
# 288564                            0
# 213591                            0
# 263083                            0
# 165001                            0
#
# [5 rows x 84 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.07560717, 0.92439283],
#        [0.14951903, 0.85048097],
#        [0.11444244, 0.88555756],
#        ...,
#        [0.02729033, 0.97270967],
#        [0.04017805, 0.95982195],
#        [0.04782141, 0.95217859]])

# %%
y_hat_test_proba[: ][: , 1]
# Out:
# array([0.92439283, 0.85048097, 0.88555756, ..., 0.97270967, 0.95982195,
#        0.95217859])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]

# %%
y_hat_test_proba
# Out:
# array([0.92439283, 0.85048097, 0.88555756, ..., 0.97270967, 0.95982195,
#        0.95217859])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
print(type(y_hat_test_proba))
print(np.array(y_hat_test_proba).shape)
# Out:
# <class 'numpy.ndarray'>
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1          0.924393
# 288564                       1          0.850481
# 213591                       1          0.885558
# 263083                       1          0.938726
# 165001                       1          0.968486
